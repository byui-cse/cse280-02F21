# %% [markdown]
# # <font color=blue>Learn About Finding Paths in Graphs</font>
# ## <font color=blue>Solutions</font>

# %% [markdown]
# ![eleven-node-seventeen-link-graph-with-nodes-labeled.png](attachment:eleven-node-seventeen-link-graph-with-nodes-labeled.png)

# %% [markdown]
# ### <font color=red>**DONE** Set up for Practice</font>

# %% [markdown]
# * Label each node of the graph.
# * Create a list of each link (pair of nodes) in the graph.

# %%
graph_links = [('A', 'B'), ('A', 'D'), ('B', 'C'), ('B', 'E'), ('C', 'F'), ('C', 'G'), ('C', 'J'), ('D', 'E'), ('D', 'H'), ('D', 'I'), ('E', 'G'), ('F', 'J'), ('G', 'H'), ('G', 'K'), ('H', 'I'), ('I', 'K'), ('K', 'J')]
graph_nodes = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K']
graph = (graph_nodes, graph_links)

# %% [markdown]
# ### <font color=red>**DONE** Trace DFS Algorithm</font>

# %% [markdown]
# * List the nodes in the order they are visited (call `DFS(graph)` after modifying the `return` statement (see below)):

# %%
['A', 'D', 'H', 'G', 'C', 'F', 'J', 'K', 'I', 'B', 'E']

# %% [markdown]
# * Modify the DFS function to behave as if the documentation string below described it.

# %%
  """Implements a depth-first search traversal
     of a given graph G = (N, L). Returns a list
     of nodes in the order they were first
     encountered by the DFS traversal.
  """

# %%
# replace the return in DFS with
  return list(map(lambda pair: pair[0], sorted(marked.items(), key = lambda item: item[1])))

# %% [markdown]
# ### <font color=red>**DONE** Trace BFS Algorithm</font>

# %% [markdown]
# * List the nodes in the order they are visited (call `BFS(graph)` after modifying the `return` statement (see below)):

# %%
['A', 'D', 'B', 'H', 'I', 'E', 'C', 'G', 'K', 'F', 'J']

# %% [markdown]
# * Modify the BFS function to behave as if the documentation string below described it.

# %%
  """Implements a breadth-first search traversal
     of a given graph G = (N, L). Returns a list
     of nodes in the order they were first
     encountered by the BFS traversal.
  """

# %%
# replace the return in BFS with
  return list(map(lambda pair: pair[0], sorted(marked.items(), key = lambda item: item[1])))
