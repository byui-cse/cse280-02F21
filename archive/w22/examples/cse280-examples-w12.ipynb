# %%
# psuedograph
dot = '''
graph { 
  layout=dot
  node [shape=circle]
  1--2--3--1
  1--1
  2--2
  3--3
}'''
from graphviz import Source
Source(dot)

# %%
# psuedograph
dot = '''
graph { 
  layout=dot
  node [shape=circle]
  1--2--3--4--1
  1--5
  2--5
  3--5
  4--5
  1--1
  2--2
  3--3
  4--4
}'''
from graphviz import Source
Source(dot)

# %%
dot = '''
graph { 
  layout=neato
  node [shape=circle]
  a--b;
  a--c;
  c--d;
  d--e;
  d--i;
  d--k;
  k--j;
  i--j;
  j--g;
  g--h;
  h--i;
  i--f;
  f--c;
  f--b;
  h--b;
  g--b;  
  e--k;
}'''
from graphviz import Source
Source(dot)

# %%
dot = '''
graph { 
  layout=neato
  node [shape=circle]
  a--b;
  b--c;
  a--c;
  c--d;
  d--e;
  d--f;
  e--f;
  e--h;
  h--i;
  h--g;
  g--j;
  g--f;

}'''
from graphviz import Source
Source(dot)

# %%
# DFS starting at "a"
dot = '''
graph { 
  layout=dot
  node [shape=circle]
  a--b;
  b--c;
  c--d
  d--e
  e--h
  h--i
  h--g
  g--j
  g--f
}'''
from graphviz import Source
Source(dot)

# %%
# BFS starting at "a"
dot = '''
graph { 
  layout=dot
  node [shape=circle]
  a--b;
  a--c;
  c--d;
  d--e;
  d--f;
  e--h
  f--g
  h--i
  g--j
}'''
from graphviz import Source
Source(dot)

# %%
# DFS starting at "d"
dot = '''
graph { 
  layout=dot
  node [shape=circle]
  d--c--b--a
  d--e--h--i
  h--g--j
  g--f
}'''
from graphviz import Source
Source(dot)

# %%
# BFS starting at "d"
dot = '''
graph { 
  layout=dot
  node [shape=circle]
  d--c--b
  c--a
  d--e--h--i
  d--f--g--j
}'''
from graphviz import Source
Source(dot)
