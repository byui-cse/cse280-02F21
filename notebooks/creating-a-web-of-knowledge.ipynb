# %% [markdown]
# # <font color=blue>Creating a Web of Knowledge</font>
# ## <font color=blue>Ponder and Prove</font>

# %% [markdown]
# The goal of this exploration is to &ldquo;Make Many Connections to Make Knowledge Permanent&rdquo;.

# %% [markdown]
# Refresh what you learned [About Learning](https://colab.research.google.com/github/byui-cse/cse280-02F21/blob/main/about-learning.ipynb).
# Now is the time to prove what you pondered.

# %% [markdown]
# In the spirit of the Prophet Joseph Smith's quote, let TOK stand for Taste Of Knowledge. But another meaning is Tapestry Of Knowledge, a weaving together of many strands. Plus it means a little something more than a Web (Graph) Of Knowledge --- it is beautiful to behold as well!

# %% [markdown]
# ### <font color=purple>Examples</font>

# %% [markdown]
# The RSA graph from Chapter 8 is part of my personal WOK. Were you to make that part of yours, you would have **memorized** this graph, and also by extension, the RSA cryptosystem --- i.e., you would know how it works, what the roles/relationships of the eight players are, etc. You would **know** it.

# %% [markdown]
#   For another example, the graph below shows the connection in my mind between the conditional operator and the definition of subset --- which connection [Exercise 2.9.10](https://colab.research.google.com/github/byui-cse/cse280-02F21/blob/main/chapter-2-sets-and-logic-in-class-exercises.ipynb#scrollTo=KDCV35QDlGV9) invited you to consider way back in Week 02:

# %%
from graphviz import Source
graph = '''
digraph {
  node [fontname="Helvetica" fontsize=12]
  edge [fontname="Helvetica" fontsize=12]
  Sets [pos="0.0,5.0!"]
  SubsetOf [pos="2.0,5.0!"][label="&sube;"];
  CondOp [pos="4.0,5.0!"][label="&rarr;"];
  LgclOp [pos="7.0,5.0!"][label="Logical Operator"];
  VennDiagrams [pos="0.0,3.0!"][label="Venn Diagrams"];
  TruthTables [pos="3.0,4.0!"][label="Truth Tables"];
  Inputs [pos="5.5,3.0!"]
  Bitstrings [pos="7.0,4.0!"]
  TwoSuperN [pos="7.0,1.0!"][label="2**n"];
  Outputs [pos="3.0,3.0!"]
  Function [pos="3.0,1.0!"]
  Binary [pos="6.0,1.6!"]
  SubsetOf -> Sets [label="relationship of"];
  SubsetOf -> CondOp [label="defined by"];
  CondOp -> LgclOp [label="a type of"];
  TruthTables -> CondOp [label="provide encoding of"];
  Inputs -> TruthTables [label="part of"];
  Inputs -> Bitstrings [label="of length 2"];
  TwoSuperN -> Bitstrings [label="counts number of"];
  TwoSuperN -> Function [label="a very important instance of"];
  TruthTables -> Outputs [label="show"];
  Outputs -> VennDiagrams [label="map to regions of"];
  Outputs -> Inputs [label="determined by"];
  Binary -> Inputs [label="the number (2) of"];
  Binary -> Function [label="a type of"];
  Function -> Outputs [label="produces"];
  Function -> Inputs [label="receives"];
  Inputs -> Outputs [label="transformed to"];
}
'''
# Note the "neato" engine that precisely [pos]itions each node
Source(graph, engine="neato")

# %% [markdown]
# ## <font color=red>Mission: Create</font>

# %% [markdown]
# Your creative task is to create a **piece** of **your personal** [semantic network](https://en.wikipedia.org/wiki/Semantic_network) (another way to characterize it) linking together part of your discrete mathematics knowledge.

# %% [markdown]
# Rather than use the standard Exploration Rubric, your creation will be evaluated using the criteria of Quality of Connections, and Completeness:

# %% [markdown]
# ### <font color=purple>Quality of Connections (50%)</font>

# %% [markdown]
# #### <font color=brown>Level 0: I have lots of questions.</font>

# %% [markdown]
# I wish you were sitting next to me while I was studying your WOK. I'm having a hard time grasping what it is saying, or I have to take a guess at what I think you meant. I'm struggling to understand your connections.

# %% [markdown]
# #### <font color=brown>Level 1: I am a little unclear.</font>

# %% [markdown]
# I wish I had your cell phone number so I could give you a quick call to clarify. I find myself looking at your WOK, understanding what your connections are, then suddenly --- I'm pulled out by something that doesn't seem to fit.

# %% [markdown]
# #### <font color=brown>Level 2: I understand.</font>

# %% [markdown]
# Studying your WOK, I find myself stopping to consider your connections. I can trace through your graph without difficulty. Your connections make sense, and are clear and specific.

# %% [markdown]
# #### <font color=brown>Level 3: Wow!</font>

# %% [markdown]
# I want to incorporate your WOK into mine! Your connections read as complete thoughts that make sense to me. Your WOK offers new or different connections than I have ever made before.

# %% [markdown]
# ### <font color=purple>Completeness (50%)</font>

# %% [markdown]
# #### <font color=brown>Level 0</font>

# %% [markdown]
# All node or link labels are missing.

# %% [markdown]
# #### <font color=brown>Level 1</font>

# %% [markdown]
# Some node or link labels are missing.

# %% [markdown]
# #### <font color=brown>Level 2</font>

# %% [markdown]
# Most node and link labels are present.

# %% [markdown]
# #### <font color=brown>Level 3</font>

# %% [markdown]
# All node and link labels are present.
