# %% [markdown]
# Create a Finite-state Machine for the regular expression
#
# $(0 \cup 1)^*1$

# %%
dot = '''
digraph {
    rankdir=LR;
    0 [shape=none, label=""];
    node [shape=circle, label=""];
    1; 2 [shape=doublecircle];
    0 -> 1;
    1 -> 1 [label="0,1"];
    1 -> 2 [label="1"];
  }
 '''
from graphviz import Source
Source(dot)

# %%
dot = '''
digraph {
    rankdir=LR;
    0 [shape=none, label=""];
    node [shape=circle, label=""];
    1; 2 [shape=doublecircle];
    0 -> 1;
    1 -> 1 [label=0];
    1 -> 2 [label=1];
    2 -> 1 [label=0];
    2 -> 2 [label=1];
  }
 '''
from graphviz import Source
Source(dot)

# %%
# Code to draw graph for exercise 9.13.3
dot = '''
digraph {
    rankdir=LR;
    0 [shape=none, label=""];
    node [shape=circle]; s0 s1;
    node [shape=doublecircle]; s2 s3;
    0->s0;
    s0->s0 [label=1];
    s0->s1 [label=0];
    s1->s2 [label=1];
    s1->s3 [label=0];
    s3->s3 [label=0];
    s3->s2 [label=1];
    s2->s1 [label=0];
    s2->s0 [label=1];
}
'''
from graphviz import Source
Source(dot)

# %%
dot = '''
digraph {
    start [shape="none", label=""];
    node [shape="circle"];
    rankdir=LR;
    start->S1;
    S1->S2 [label="0"];
    S2->S1 [label="1"];
    S1->S1 [label="1"];
    S2->S2 [label="0"];
  }
 '''
from graphviz import Source
Source(dot)
