# %% [markdown]
# # Combinatorics

# %% [markdown]
# ## Product Rule

# %% [markdown]
# ### How many passwords?

# %%
# How many passwords of length 8 with uppercase, lowercase, and digits?

uppercase = 26
lowercase = 26
digits = 10

62**8

# %%
# How many possible combinations of DNA?

# Alphabet is {A, G, C, T}
alphabet_size = 4

# How long is the string?
# Somewhere between 4^10^5 and 4^10^8

alphabet_size ** 10 ** 5

# %%
from math import factorial
print(factorial(30) / factorial(24)) #permutation


from scipy.special import comb  #combination
comb(30,6)

# %%
# Astronauts
n = 30
r = 6
from math import factorial
result = factorial(n) / (factorial(r) * factorial(n - r))
print(result)
